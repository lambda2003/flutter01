# %% [markdown]
# # python 기초
#
# ## 사칙연산

# %%
# 덧셈
1 + 2
# Out:
# 3

# %%
# 곱셈
2 * 3
# Out:
# 6

# %%
# 나눗셈
3/2
# Out:
# 1.5

# %%
# 나머지
5%2
# Out:
# 1

# %%
# 몫
5 // 2
# Out:
# 2

# %%
# 몫과 나머지를 같이 본다
print("몫:",5 // 2, "나머지:", 5%2)
# Out:
# 몫: 2 나머지: 1

# %% [markdown]
# ### 변수에 대입하여 계산하기 (dynamic형식이라 타입을 정하는 것이 좋다)

# %%
# 변수에 정수를 할당하여 계산하기
var_1 = 2
var_2 = 5
print(var_1+var_2)
# Out:
# 7

# %%
type(var_1)
# Out:
# int

# %%
var_1 = "Python"

# %%
type(var_1)
# Out:
# str

# %% [markdown]
# > 변수의 자료형은 데이터형을 유추하여 자료형이 변경된다.

# %% [markdown]
# ---
# 조건문

# %%
var_1 = 3
if var_1 > 1:
  print('var_1 is greater than 1')
# Out:
# var_1 is greater than 1

# %% [markdown]
# ##  반복문

# %%
for i in [10, 20, 30]:
  print(i)
# Out:
# 10
# 20
# 30

# %%
i = 0
while i < 30:
  i+=10
  print(i)
# Out:
# 10
# 20
# 30

# %% [markdown]
# ---
# 함수

# %%
def sumF(num1,num2):
  return num1+num2

# %%
sumF(10,20)
# Out:
# 30
