# %%
m1 = [{"id":111,"name":"bill gates","age":1},{"id":222,"name":"Trump","age":2},{"id":333,"name":"Jayden","age":3},{"id":111,"name":"bill gates","age":4}]

print([v for v in m1 if v['age']==1])


# null, nil, None, na
# Out:
# [{'id': 111, 'name': 'bill gates', 'age': 1}]
# [{'id': 222, 'name': 'Trump', 'age': 2},
#  {'id': 333, 'name': 'Jayden', 'age': 3}]
